# %%
#Dependencies
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')

series = read_csv('Resources/shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# fit model
model = ARIMA(series, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# C:\Users\rwzlo\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3029                 result = tools.to_datetime(
# -> 3030                     date_parser(*date_cols), errors='ignore')
#    3031                 if isinstance(result, datetime.datetime):
#
# <ipython-input-1-c4676380d37f> in parser(x)
#       8 def parser(x):
# ----> 9         return datetime.strptime('190'+x, '%Y-%m')
#      10
#
# TypeError: strptime() argument 1 must be str, not numpy.ndarray
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3038                                                 parser=date_parser,
# -> 3039                                                 dayfirst=dayfirst),
#    3040                         errors='ignore')
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.try_parse_dates()
#
# <ipython-input-1-c4676380d37f> in parser(x)
#       8 def parser(x):
# ----> 9         return datetime.strptime('190'+x, '%Y-%m')
#      10
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\_strptime.py in _strptime(data_string, format)
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#
# ValueError: time data '190Sales of shampoo over a three year period' does not match format '%Y-%m'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-c4676380d37f> in <module>()
#       9         return datetime.strptime('190'+x, '%Y-%m')
#      10
# ---> 11 series = read_csv('Resources/shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#      12 # fit model
#      13 model = ARIMA(series, order=(5,1,0))
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1915
#    1916             names, data = self._do_date_conversions(names, data)
# -> 1917             index, names = self._make_index(data, alldata, names)
#    1918
#    1919         # maybe create a mi on the columns
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _make_index(self, data, alldata, columns, indexnamerow)
#    1410         elif not self._has_complex_date_col:
#    1411             index = self._get_simple_index(alldata, columns)
# -> 1412             index = self._agg_index(index)
#    1413         elif self._has_complex_date_col:
#    1414             if not self._name_processed:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _agg_index(self, index, try_parse_dates)
#    1491
#    1492             if (try_parse_dates and self._should_parse_dates(i)):
# -> 1493                 arr = self._date_conv(arr)
#    1494
#    1495             if self.na_filter:
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\parsers.py in converter(*date_cols)
#    3040                         errors='ignore')
#    3041                 except Exception:
# -> 3042                     return generic_parser(date_parser, *date_cols)
#    3043
#    3044     return converter
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\pandas\io\date_converters.py in generic_parser(parse_func, *cols)
#      37     for i in range(N):
#      38         args = [c[i] for c in cols]
# ---> 39         results[i] = parse_func(*args)
#      40
#      41     return results
#
# <ipython-input-1-c4676380d37f> in parser(x)
#       7
#       8 def parser(x):
# ----> 9         return datetime.strptime('190'+x, '%Y-%m')
#      10
#      11 series = read_csv('Resources/shampoo-sales.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~\AppData\Local\conda\conda\envs\PythonData\lib\_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '190Sales of shampoo over a three year period' does not match format '%Y-%m'
